# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.arange(-10, 10, 0.01)
y = x*x - 5*x + 1
fig = plt.figure() # step 1:创建一个画板实例figure
ax = fig.add_subplot(111) # step 2:使用画板穿件一个或多个轴区实例Axes
ax.plot(x, y, 'r--') # step 3:使用轴区实例的相关方法进行绘图
plt.show()

# %%
x = np.arange(-10, 10, 0.01)
y = x*x - 5*x + 1
plt.plot(x, y, 'r--')
plt.show()

# %%
plt.plot?

# %%
a = np.arange(10)
plt.plot(a, a*1.5, a, a*2.5,
         a, a*3.5, a, a*4.5)
plt.show()

# %%
a = np.arange(10)
plt.plot(a, a*1.5,':', a, a*2.5,'-.',
         a, a*3.5,'-', a, a*4.5)
plt.show()

# %%
a = np.arange(10)
plt.plot(a, a*1.5,'go', a, a*2.5,'rx',
         a, a*3.5,'*', a, a*4.5,'b-.')
plt.show()

# %%
import matplotlib
matplotlib.rcParams['font.family'] = ['SimHei']
#mac下的中文字体
# matplotlib.rcParams["font.family"] = 'Arial Unicode MS'
plt.plot([3,1,4,5,2])
plt.ylabel("纵轴（值）")
plt.show()

# %%
a = np.arange(0.0, 5.0, 0.02)
plt.xlabel('时间',fontproperties='SimHei',fontsize=20)
plt.ylabel('振幅',fontproperties='SimHei',fontsize=20)
# plt.xlabel('时间',fontproperties='Arial Unicode MS',fontsize=20)
# plt.ylabel('振幅',fontproperties='Arial Unicode MS',fontsize=20)
plt.plot(a, np.cos(2*np.pi*a), 'r--')
plt.show()
# Out:
# /Users/kms/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/kms/opt/anaconda3/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
plt.rcParams['axes.unicode_minus'] = False #解决负号乱码
def f(t):
    return np.exp(-t)*np.cos(2*np.pi*t)
a = np.arange(0.0, 5.0, 0.02)
plt.subplot(211)
plt.plot(a,f(a))

plt.subplot(2,1,2)
plt.plot(a,np.cos(2*np.pi*a),'r--')
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.subplot2grid((3,3),(0,0),colspan=3)
plt.subplot2grid((3,3),(1,0),colspan=2)
plt.subplot2grid((3,3),(1,2),rowspan=2)
plt.subplot2grid((3,3),(2,0))
plt.subplot2grid((3,3),(2,1))

# %%
import matplotlib.gridspec as gridspec
plt.figure(figsize=(8,5))
gs = gridspec.GridSpec(3,3)
ax1 = plt.subplot(gs[0,:])
ax2 = plt.subplot(gs[1,:-1])
ax3 = plt.subplot(gs[1:,-1])
ax4 = plt.subplot(gs[2,0])
ax5 = plt.subplot(gs[2,1])

# %%
a = np.arange(0.0,5.0,0.02)
plt.plot(a, np.cos(2*np.pi*a),'r--')

plt.xlabel('时间',fontproperties='SimHei',fontsize=20)
plt.ylabel('振幅',fontproperties='SimHei',fontsize=20)
plt.title(r'正弦波实例 $y=cos(2\pi x)$',fontproperties='SimHei',fontsize=20)
# plt.xlabel('时间',fontproperties='Arial Unicode MS',fontsize=20)
# plt.ylabel('振幅',fontproperties='Arial Unicode MS',fontsize=20)
# plt.title(r'正弦波实例 $y=cos(2\pi x)$',fontproperties='Arial Unicode MS',fontsize=20)
plt.text(2,1,r'$\mu=100$',fontsize=25)

plt.axis([-1,6,-2,2])
plt.grid(True)
plt.show()

# %%
a = np.arange(0.0,5.0,0.02)
plt.plot(a, np.cos(2*np.pi*a),'r--')

plt.xlabel('时间',fontproperties='SimHei',fontsize=20)
plt.ylabel('振幅',fontproperties='SimHei',fontsize=20)
plt.title(r'正弦波实例 $y=cos(2\pi x)$',fontproperties='SimHei',fontsize=20)
# plt.xlabel('时间',fontproperties='Arial Unicode MS',fontsize=20)
# plt.ylabel('振幅',fontproperties='Arial Unicode MS',fontsize=20)
# plt.title(r'正弦波实例 $y=cos(2\pi x)$',fontproperties='Arial Unicode MS',fontsize=20)
plt.annotate(r'$\mu=100$',xy=(2,1),xytext=(3,1.5),arrowprops=dict(facecolor='black',shrink=0.1,width=2))

plt.axis([-1,6,-2,2])
plt.grid(True)
plt.show()

# %% [markdown]
# ## Q1-利用我们学到的知识，生成下面的图片：

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y1, y2, y3 = np.cos(x), np.cos(x + 1), np.cos(x + 2)
names = ['Signal 1', 'Signal 2', 'Signal 3']

for index in np.arange(0,3,1):
  plt.figure(figsize=(8,5))
  plt.subplot(3,1,index+1)
  plt.plot(x,[y1,y2,y3][index])
  plt.title(names[index])

# %% [markdown]
# ## Q2-利用我们学到的知识，生成下面的图片：

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure()
plt.subplot(2,1,1)
plt.plot([0,1],[0,1])
plt.subplot(2,3,4)
plt.plot([0,1],[0,2])
plt.subplot(2,3,5)
plt.plot([0,1],[0,3])
plt.subplot(2,3,6)
plt.plot([0,1],[0,4])
plt.show()

# %% [markdown]
# ##  Q3-利用下面的代码可以生成图中蓝色的线，请补充代码实现下图：

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

x = np.arange(9)
y = np.sin(x)
z = np.cos(x)
# marker数据点样式，linewidth线宽，linestyle线型样式，color颜色
plt.plot(x, y, marker="*", linewidth=3, linestyle="--", color="orange")
plt.plot(x, z)
plt.title("matplotlib")
#设置xlabel ylabel
plt.xlabel("height")
plt.ylabel("width")
# 设置图例
plt.legend(["Y","Z"], loc="upper right")
plt.grid(True)
plt.show()
